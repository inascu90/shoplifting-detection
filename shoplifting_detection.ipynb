# %% [markdown]
# <a href="https://colab.research.google.com/github/inascu90/shoplifting-detection/blob/main/shoplifting_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mateohervas/dcsass-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/mateohervas/dcsass-dataset?dataset_version_number=1...
# 100%|██████████| 1.35G/1.35G [00:23<00:00, 61.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1

# %%
import zipfile
import os

def unzip_file(zip_file, extract_to):
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

# Replace 'folder_archiv.zip' with the actual name of your ZIP file
zip_file = 'archive.zip'

# Replace 'extracted_folder' with the directory where you want to extract the contents
extract_to = 'extracted_folder'

# Create the extraction directory if it doesn't exist
if not os.path.exists(extract_to):
    os.makedirs(extract_to)
if not os.path.exists(zip_file):
    print(f"{zip_file} does not exist")
else:
    print('zzzzz')
    unzip_file(zip_file, extract_to)

# # Call the function to unzip the file
# unzip_file(zip_file, extract_to)

print("Extraction complete!")
# Out:
# archive.zip does not exist
# Extraction complete!

# %%
import pandas as pd
df = pd.read_csv("/root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Labels/Shoplifting.csv")

# %%
df.drop("Shoplifting",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Shoplifting001_x264_0  0
# 0  Shoplifting001_x264_1  0
# 1  Shoplifting001_x264_2  0
# 2  Shoplifting001_x264_3  0
# 3  Shoplifting001_x264_4  0
# 4  Shoplifting001_x264_5  0

# %%
# import pandas as pd

# # Assuming df is your DataFrame
# df["Shoplifting001_x264_0"] = df["Shoplifting001_x264_0"].apply(lambda x: "/content/extracted_folder/DCSASS Dataset/Shoplifting/" + x + ".mp4" )

# # Display the updated DataFrame

# %%
df["Shoplifting001_x264_0"] = df["Shoplifting001_x264_0"].apply(
    lambda x: "/root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/" + x.split('_')[0] + '_' + x.split('_')[1] + ".mp4/" + x + ".mp4"
)

# %%
df.head()
# Out:
#                                Shoplifting001_x264_0  0
# 0  /root/.cache/kagglehub/datasets/mateohervas/dc...  0
# 1  /root/.cache/kagglehub/datasets/mateohervas/dc...  0
# 2  /root/.cache/kagglehub/datasets/mateohervas/dc...  0
# 3  /root/.cache/kagglehub/datasets/mateohervas/dc...  0
# 4  /root/.cache/kagglehub/datasets/mateohervas/dc...  0

# %%
df = df.rename(columns={'Shoplifting001_x264_0': 'path', '0': 'target'})

# %%
df.head()
# Out:
#                                                 path  target
# 0  /root/.cache/kagglehub/datasets/mateohervas/dc...       0
# 1  /root/.cache/kagglehub/datasets/mateohervas/dc...       0
# 2  /root/.cache/kagglehub/datasets/mateohervas/dc...       0
# 3  /root/.cache/kagglehub/datasets/mateohervas/dc...       0
# 4  /root/.cache/kagglehub/datasets/mateohervas/dc...       0

# %%
import os
import cv2
import pandas as pd

# Function to extract frames from a video
def extract_frames(video_path, target, output_dir, start_index):
    frame_count = 0

    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Loop through the video frames
    while cap.isOpened():
        print('any')
        ret, frame = cap.read()
        if not ret:
            break

        # Save the frame based on the target
        if target == 0:
            frame_dir = os.path.join(output_dir, "normal")
        else:
            frame_dir = os.path.join(output_dir, "abnormal")

        if not os.path.exists(frame_dir):
            os.makedirs(frame_dir)

        cv2.imwrite(os.path.join(frame_dir, f"frame_{start_index + frame_count}.jpg"), frame)
        frame_count += 1

    cap.release()

# Read the DataFrame
# df = pd.read_csv("your_dataframe.csv")  # Replace "your_dataframe.csv" with the actual CSV file path
#df = pd.read_csv("/content/extracted_folder/DCSASS Dataset/Shoplifting")
#df = pd.read_csv("/content/extracted_folder/DCSASS Dataset/Shoplifting/Shoplifting001_x264.mp4")
# Create output directory if it doesn't exist
output_dir = "output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

i = 0
# Iterate through each row of the DataFrame
for index, row in df.iterrows():
    video_path = row['path'].strip()
    target = row['target']
    print('video_path',video_path)

    # Extract frames based on the target
    extract_frames(video_path, target, output_dir, i)
    i =i+ 1000

print("Frame extraction completed.")
# Out:
# Streaming output truncated to the last 5000 lines.
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_0.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_1.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_2.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_3.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_4.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_5.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_6.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_7.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_8.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_9.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_10.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_11.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_12.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_13.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_14.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_15.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_16.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_17.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_18.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_19.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_20.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_21.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_22.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_23.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_24.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_25.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_26.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_27.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_28.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_29.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_30.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting050_x264.mp4/Shoplifting050_x264_31.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_0.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_1.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_2.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_3.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_4.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_5.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_6.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_7.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_8.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_9.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_10.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_11.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_12.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_13.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_14.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_15.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_16.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_17.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_18.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_19.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_20.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_21.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_22.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_23.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_24.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_25.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_26.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_27.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_28.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_29.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_30.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting053_x264.mp4/Shoplifting053_x264_31.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_0.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_1.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_2.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_3.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_4.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_5.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_6.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_7.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_8.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_9.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_10.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_11.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_12.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_13.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_14.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_15.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_16.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_17.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_18.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_19.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_20.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_21.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_22.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_23.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_24.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_25.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_26.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_27.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_28.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_29.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_30.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# video_path /root/.cache/kagglehub/datasets/mateohervas/dcsass-dataset/versions/1/DCSASS Dataset/Shoplifting/Shoplifting054_x264.mp4/Shoplifting054_x264_31.mp4
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# any
# Frame extraction completed.

# %%
df.head()
# Out:
#                                                 path  target
# 0  /root/.cache/kagglehub/datasets/mateohervas/dc...       0
# 1  /root/.cache/kagglehub/datasets/mateohervas/dc...       0
# 2  /root/.cache/kagglehub/datasets/mateohervas/dc...       0
# 3  /root/.cache/kagglehub/datasets/mateohervas/dc...       0
# 4  /root/.cache/kagglehub/datasets/mateohervas/dc...       0

# %%
import os
import random
import shutil

# Define the paths
output_normal_dir = "output/normal"
test_normal_dir = "test/normal"

# Create the test/normal directory if it doesn't exist
if not os.path.exists(test_normal_dir):
    os.makedirs(test_normal_dir)

# List all files in the output/normal directory
files = os.listdir(output_normal_dir)

# Calculate the number of files to move (20%)
num_files_to_move = int(0.2 * len(files))

# Randomly select files to move
files_to_move = random.sample(files, num_files_to_move)

# Move the selected files to the test/normal directory
for file_name in files_to_move:
    src = os.path.join(output_normal_dir, file_name)
    dst = os.path.join(test_normal_dir, file_name)
    shutil.move(src, dst)

print("Images moved to the test/normal directory.")
# Out:
# Images moved to the test/normal directory.

# %%
import os
import random
import shutil

# Define the paths
output_normal_dir = "output/abnormal"
test_normal_dir = "test/abnormal"

# Create the test/normal directory if it doesn't exist
if not os.path.exists(test_normal_dir):
    os.makedirs(test_normal_dir)

# List all files in the output/normal directory
files = os.listdir(output_normal_dir)

# Calculate the number of files to move (20%)
num_files_to_move = int(0.2 * len(files))

# Randomly select files to move
files_to_move = random.sample(files, num_files_to_move)

# Move the selected files to the test/normal directory
for file_name in files_to_move:
    src = os.path.join(output_normal_dir, file_name)
    dst = os.path.join(test_normal_dir, file_name)
    shutil.move(src, dst)

print("Images moved to the test/normal directory.")
# Out:
# Images moved to the test/normal directory.

# %%
2.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
# #         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside

# %%
train_dir = "/content/output"
test_dir = "/content/test"

# %%
import tensorflow as tf

# %%
# Create early stopping (once our model stops improving, stop training)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy",
                                                  patience=2) # stop

# %%
IMG_SIZE = (224, 224) # define image size
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory=train_dir,
                                                                            image_size=IMG_SIZE,
                                                                            label_mode="categorical", # what type are the labels?
                                                                            batch_size=32) # batch_size is 32 by default, this is generally a good number
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory=test_dir,
                                                                           image_size=IMG_SIZE,
                                                                           label_mode="categorical")
# Out:
# Found 49056 files belonging to 2 classes.
# Found 12264 files belonging to 2 classes.

# %%
classes=train_data.class_names

# %%
classes
# Out:
# ['abnormal', 'normal']

# %%
# How many rounds should we get the model to look through the data?
NUM_EPOCHS = 50 #@param {type:"slider", min:10, max:100, step:10}

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# from tensorflow.keras.layers.experimental import preprocessing

# NEW: Newer versions of TensorFlow (2.10+) can use the tensorflow.keras.layers API directly for data augmentation
data_augmentation = keras.Sequential([
  layers.RandomFlip("horizontal"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(0.2),
  layers.RandomHeight(0.2),
  layers.RandomWidth(0.2),
  # preprocessing.Rescaling(1./255) # keep for ResNet50V2, remove for EfficientNetV2B0
], name ="data_augmentation")

# %%
from tensorflow.keras import layers
from tensorflow.keras import regularizers
import tensorflow as tf

# Create base model
input_shape = (224, 224, 3)
base_model = tf.keras.applications.efficientnet_v2.EfficientNetV2B0(include_top=False)
base_model.trainable = False  # freeze base model layers

# Create Functional model
inputs = layers.Input(shape=input_shape, name="input_layer")
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D(name="pooling_layer")(x)

# Add L2 regularization to the Dense layer
x = layers.Dense(2, kernel_regularizer=regularizers.l2(0.001))(x)

# Separate activation of output layer so we can output float32 activations
outputs = layers.Activation("sigmoid", dtype=tf.float32, name="output")(x)
model = tf.keras.Model(inputs, outputs)

# Compile the model
model.compile(
    loss="binary_crossentropy",  # Use binary crossentropy for binary classification
    optimizer=tf.keras.optimizers.Adam(),
    metrics=["accuracy"]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Make the creating of our model a little easier
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, Activation
from tensorflow.keras import Sequential

# %%
# Train the model
model.fit(train_data, epochs=5
          , validation_data=test_data,callbacks=[ early_stopping])
# Out:
# Epoch 1/5
# 1533/1533 ━━━━━━━━━━━━━━━━━━━━ 146s 77ms/step - accuracy: 0.8491 - loss: 0.3700 - val_accuracy: 0.8775 - val_loss: 0.2982
# Epoch 2/5
# 1533/1533 ━━━━━━━━━━━━━━━━━━━━ 101s 66ms/step - accuracy: 0.8746 - loss: 0.3051 - val_accuracy: 0.8893 - val_loss: 0.2828
# Epoch 3/5
# 1533/1533 ━━━━━━━━━━━━━━━━━━━━ 102s 66ms/step - accuracy: 0.8825 - loss: 0.2956 - val_accuracy: 0.8883 - val_loss: 0.2791
# Epoch 4/5
# 1533/1533 ━━━━━━━━━━━━━━━━━━━━ 101s 66ms/step - accuracy: 0.8850 - loss: 0.2918 - val_accuracy: 0.8950 - val_loss: 0.2769
# Epoch 5/5
# 1533/1533 ━━━━━━━━━━━━━━━━━━━━ 165s 81ms/step - accuracy: 0.8868 - loss: 0.2906 - val_accuracy: 0.8892 - val_loss: 0.2751

# %%
#model.load_weights('file.h5')

# %%
test_loss, test_accuracy = model.evaluate(test_data)

# Predict on test data
predictions = model.predict(test_data)
# Out:
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - accuracy: 0.8889 - loss: 0.2756
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 30s 61ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Get true labels
true_labels = []
for images, labels in test_data:
    true_labels.extend(tf.argmax(labels, axis=1).numpy())

# Convert probabilities to binary predictions
binary_predictions = (predictions > 0.5).astype(int)

# Flatten the predictions if needed
binary_predictions = binary_predictions.argmax(axis=1)

# Calculate accuracy
accuracy = accuracy_score(true_labels, binary_predictions)

# Calculate precision
precision = precision_score(true_labels, binary_predictions)

# Calculate recall
recall = recall_score(true_labels, binary_predictions)

# Calculate F1 score
f1 = f1_score(true_labels, binary_predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.7852250489236791
# Precision: 0.8377852467716257
# Recall: 0.9221183800623053
# F1 Score: 0.8779312262489573

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.efficientnet import preprocess_input
import matplotlib.pyplot as plt
from IPython.display import display
import ipywidgets as widgets

# Load the Keras model
# model = load_model('../input/your_model_directory/my_model.keras')  # Update with your model path

# Define your classes
classes = ['abnormal', 'normal']

# Function to preprocess the image for EfficientNetB0
def preprocess_image(img):
    img = tf.convert_to_tensor(img, dtype=tf.float32)
    img = tf.image.resize(img, [224, 224])
    img = np.expand_dims(img, axis=0)
    # img = preprocess_input(img)  # If needed
    return img

# Function to perform classification and overlay results on the frame
def classify_frame(frame):
    # Preprocess the frame
    processed_frame = preprocess_image(frame)

    # Make prediction
    predictions = model.predict(processed_frame)

    # Get the index of the predicted class
    predicted_class_index = np.argmax(predictions[0])

    # Get the class label
    predicted_class = classes[predicted_class_index]

    # Get the confidence score
    confidence = predictions[0][predicted_class_index]

    # Overlay predictions on the frame
    label_text = f"Class: {predicted_class} (Confidence: {confidence:.2f})"
    cv2.putText(frame, label_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    return frame

# Path to the video file (update with your file path)
#video_path = '/kaggle/input/dcsass-dataset/DCSASS Dataset/Shoplifting/Shoplifting005_x264.mp4/Shoplifting005_x264_13.mp4'  # Update with your video path
video_path='/content/test/normal/frame_103109.jpg'
# Open the video file
cap = cv2.VideoCapture(video_path)

# Define a flag for breaking the loop
stop_button = widgets.Button(description='Stop')
display(stop_button)

def stop_callback(button):
    cap.release()

stop_button.on_click(stop_callback)

while cap.isOpened():
    # Read a frame from the video
    ret, frame = cap.read()

    # Break the loop if the video is finished
    if not ret:
        break

    # Classify the frame
    classified_frame = classify_frame(frame)

    # Convert the frame from BGR to RGB
    classified_frame_rgb = cv2.cvtColor(classified_frame, cv2.COLOR_BGR2RGB)

    # Display the frame using Matplotlib
    plt.imshow(classified_frame_rgb)
    plt.axis('off')
    plt.show()
# Out:
# Button(description='Stop', style=ButtonStyle())
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
model.save('shoplifting.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
